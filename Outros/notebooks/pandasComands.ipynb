# %% [markdown]
# ## Comandos básicos Pandas
# Aqui fiz uma breve resumida de alguns comandos em Pandas para uso próprio

# %% [markdown]
# ### Leitura de dados
# Importação do Pandas e outras bibliotecas:

# %%
import pandas as pd

# %% [markdown]
# Arquivos CSV:

# %% [markdown]
# Documentação: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html

# %%
# Para ler arquivos CSV usamos:
# Forma padrão de leitura:
df = pd.read_csv("nome_do_arquivo.csv")
# Caso haja um separador diferente de ',' usamos o comando sep:
df = pd.read_csv("nome_do_arquivo.csv", sep= ';')

# %%
# Arquivos codificados em ISO (as ISO são tratamentos diferentes como : ç, ã etc.:
df = pd.read_csv('nome_do_arquivo.csv', encoding='ISO-8859-1')
# Leitura de dados diretamente pela internet:
df = pd.read_csv('https://raw.githubusercontent.com/FBosler/you- datascientist/master/happiness_with_continent.csv')

# %%
# nós também podemos usar o 'header' que muda o cabeçalho das colunas
df = pd.read_csv('nome_do_arquivo.csv', encoding='UTF-8', header = 1)

# %% [markdown]
# Outros comandos na execução do CSV:

# %%
# Selecionando apenas algumas colunas - usamos o usecols 
df2 = pd.read_csv("dados.csv", usecols=["bairro", "preco"])
df2.head(3)

# %%
# Selecionando apenas algumas linhas - usamos o nrows 
df2 = pd.read_csv("dados.csv", nrows = 200)

df2.shape

# %%
# Ou tudo de uma vez ;D
df2 = pd.read_csv("dados.csv", usecols=["bairro", "preco"], nrows = 200)
df2

# %% [markdown]
# Arquivos EXCEL:

# %% [markdown]
# Documentação: http://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_excel.html

# %%
# Para ler arquivos EXCEL usamos:
df = pd.read_excel("Nomedoarquivo.xlsx")

# %%
# Especificando qual aba irá abrir
df = pd.read_excel("Nomedoarquivo.xlsx", sheet_name=0)
# Também podemos colocar o nome da aba
df = pd.read_excel("Nomedoarquivo.xlsx", sheet_name='Tab1')

# %%
# Verificar os nomes das abas com sheet_names
arquivo_excel.sheet_names

# %%
# usando PARSE para selecionar as abas
aba1 = arquivo_excel.parse("Aba1")
aba2 = arquivo_excel.parse("Aba2")

# %% [markdown]
# ### Testes e comandos:

# %%
df = pd.read_csv('bank.csv', encoding='UTF-8', sep = ";")

# %%
# Para trazer os primeiros elementos usamos o head
df.head(3)
# Out:
#    age         job  marital  education default  balance housing loan  \
# 0   30  unemployed  married    primary      no     1787      no   no
# 1   33    services  married  secondary      no     4789     yes  yes
# 2   35  management   single   tertiary      no     1350     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no

# %%
# Para trazer os últimos elementos usamos o tail
df.tail(3)
# Out:
#       age           job  marital  education default  balance housing loan  \
# 4518   57    technician  married  secondary      no      295      no   no
# 4519   28   blue-collar  married  secondary      no     1137      no   no
# 4520   44  entrepreneur   single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 4518  cellular   19   aug       151        11     -1         0  unknown  no
# 4519  cellular    6   feb       129         4    211         3    other  no
# 4520  cellular    3   apr       345         2    249         7    other  no

# %%
# o df.T inverte o dataframe, colunas viram linhas e linhas viram colunas
df.T
# Out:
#                  0          1           2           3            4     \
# age                30         33          35          30           59
# job        unemployed   services  management  management  blue-collar
# marital       married    married      single     married      married
# education     primary  secondary    tertiary    tertiary    secondary
# default            no         no          no          no           no
# balance          1787       4789        1350        1476            0
# housing            no        yes         yes         yes          yes
# loan               no        yes          no         yes           no
# contact      cellular   cellular    cellular     unknown      unknown
# day                19         11          16           3            5
# month             oct        may         apr         jun          may
# duration           79        220         185         199          226
# campaign            1          1           1           4            1
# pdays              -1        339         330          -1           -1
# previous            0          4           1           0            0
# poutcome      unknown    failure     failure     unknown      unknown
# y                  no         no          no          no           no
#
#                  5              6           7             8         9     ...  \
# age                35             36          39            41        43  ...
# job        management  self-employed  technician  entrepreneur  services  ...
# marital        single        married     married       married   married  ...
# education    tertiary       tertiary   secondary      tertiary   primary  ...
# default            no             no          no            no        no  ...
# balance           747            307         147           221       -88  ...
# housing            no            yes         yes           yes       yes  ...
# loan               no             no          no            no       yes  ...
# contact      cellular       cellular    cellular       unknown  cellular  ...
# day                23             14           6            14        17  ...
# month             feb            may         may           may       apr  ...
# duration          141            341         151            57       313  ...
# campaign            2              1           2             2         1  ...
# pdays             176            330          -1            -1       147  ...
# previous            3              2           0             0         2  ...
# poutcome      failure          other     unknown       unknown   failure  ...
# y                  no             no          no            no        no  ...
#
#                   4511         4512         4513         4514       4515  \
# age                 46           40           49           38         32
# job        blue-collar  blue-collar  blue-collar  blue-collar   services
# marital        married      married      married      married     single
# education    secondary    secondary    secondary    secondary  secondary
# default             no           no           no           no         no
# balance            668         1100          322         1205        473
# housing            yes          yes           no          yes        yes
# loan                no           no           no           no         no
# contact        unknown      unknown     cellular     cellular   cellular
# day                 15           29           14           20          7
# month              may          may          aug          apr        jul
# duration          1263          660          356           45        624
# campaign             2            2            2            4          5
# pdays               -1           -1           -1          153         -1
# previous             0            0            0            1          0
# poutcome       unknown      unknown      unknown      failure    unknown
# y                  yes           no           no           no         no
#
#                 4516           4517        4518         4519          4520
# age               33             57          57           28            44
# job         services  self-employed  technician  blue-collar  entrepreneur
# marital      married        married     married      married        single
# education  secondary       tertiary   secondary    secondary      tertiary
# default           no            yes          no           no            no
# balance         -333          -3313         295         1137          1136
# housing          yes            yes          no           no           yes
# loan              no            yes          no           no           yes
# contact     cellular        unknown    cellular     cellular      cellular
# day               30              9          19            6             3
# month            jul            may         aug          feb           apr
# duration         329            153         151          129           345
# campaign           5              1          11            4             2
# pdays             -1             -1          -1          211           249
# previous           0              0           0            3             7
# poutcome     unknown        unknown     unknown        other         other
# y                 no             no          no           no            no
#
# [17 rows x 4521 columns]

# %%
# Para trazer a quantidade de (linhas, colunas)
df.shape
# Out:
# (4521, 17)

# %%
# Traz o index (ID)
df.index
# Out:
# RangeIndex(start=0, stop=4521, step=1)

# %%
# Retorna todas as colunas de um dataframe
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
# Para retornar as colunas de uma coluna usamos o comando 'unique' que repete apenas uma vez
df["marital"].unique()
# Out:
# array(['married', 'single', 'divorced'], dtype=object)

# %%
# Mostra o tipo de cada uma das colunas
df.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %%
# Correlação de cada uma das colunas
df.corr()
# Out:
#                age   balance       day  duration  campaign     pdays  previous
# age       1.000000  0.083820 -0.017853 -0.002367 -0.005148 -0.008894 -0.003511
# balance   0.083820  1.000000 -0.008677 -0.015950 -0.009976  0.009437  0.026196
# day      -0.017853 -0.008677  1.000000 -0.024629  0.160706 -0.094352 -0.059114
# duration -0.002367 -0.015950 -0.024629  1.000000 -0.068382  0.010380  0.018080
# campaign -0.005148 -0.009976  0.160706 -0.068382  1.000000 -0.093137 -0.067833
# pdays    -0.008894  0.009437 -0.094352  0.010380 -0.093137  1.000000  0.577562
# previous -0.003511  0.026196 -0.059114  0.018080 -0.067833  0.577562  1.000000

# %%
# Conta a quantidade de dados (Não nulos)
df.count()
# Out:
# age          4521
# job          4521
# marital      4521
# education    4521
# default      4521
# balance      4521
# housing      4521
# loan         4521
# contact      4521
# day          4521
# month        4521
# duration     4521
# campaign     4521
# pdays        4521
# previous     4521
# poutcome     4521
# y            4521
# dtype: int64

# %%
# Conta a quantidade de dados de uma coluna
df['contact'].value_counts()
# Out:
# cellular     2896
# unknown      1324
# telephone     301
# Name: contact, dtype: int64

# %%
# Chamada de uma coluna
df['marital'].head(3)
# Out:
# 0    married
# 1    married
# 2     single
# Name: marital, dtype: object

# %%
# Chamada de duas colunas
df[['marital', 'age']].head(3)
# Out:
#    marital  age
# 0  married   30
# 1  married   33
# 2   single   35

# %%
# Também podemos selecionar com o '.' porém apenas uma de cada vez
df.job.head(3)
# Out:
# 0    unemployed
# 1      services
# 2    management
# Name: job, dtype: object

# %%
# Alterar nome das colunas (implace serve para mudar a base de dados e a atualiza-la)
df.rename(columns = {'age':'idade'}, inplace = True)

# %%
# com o at podemos acessar ['numero do id da linha', 'nome da coluna']
df.at[0, 'education']
# Out:
# 'primary'

# %%
# Apagar uma linha - (inplace atualiza a base de dados diretamente)
df.drop(4520, axis = 0, inplace = True)
# Apagar uma coluna
df.drop('pdays', axis = 1, inplace = True)

#Obs: (caso  o axis = 0 significa linha, caso o axis = 1 significa coluna)

# %% [markdown]
# Comando Loc e Iloc:

# %%
# Usando o Loc

# retorna apenas a linha 0
df.loc[0]
# retorna da linha 0 a linha 5
df.loc[0:5]
# retorna as linhas 0, 5, 10
df.loc[[1, 5, 10]]
# Out:
#     idade         job  marital  education default  balance housing loan  \
# 1      33    services  married  secondary      no     4789     yes  yes
# 5      35  management   single   tertiary      no      747      no   no
# 10     39    services  married  secondary      no     9374     yes   no
#
#      contact  day month  duration  campaign  previous poutcome   y
# 1   cellular   11   may       220         1         4  failure  no
# 5   cellular   23   feb       141         2         3  failure  no
# 10   unknown   20   may       273         1         0  unknown  no

# %%
# Retorna as linhas 1, 5, 10 e apenas da coluna marital
df.loc[[1, 5, 10], "marital"]
# Retorna as linhas 4 até a 6 e apenas da coluna bairro e da coluna preco
df.loc[4:6, ["marital", "education"]]
# Out:
#    marital  education
# 4  married  secondary
# 5   single   tertiary
# 6  married   tertiary

# %%
# com o loc podemos 'localizar' oque buscamos [[Número dos ids (podem ser vários)], 'Nome da coluna':'até a 'outra coluna']
# da colunas Idade até a colunas Education
df.loc[[0, 1, 2, 3], "idade":"education"]
# Out:
#    idade         job  marital  education
# 0     30  unemployed  married    primary
# 1     33    services  married  secondary
# 2     35  management   single   tertiary
# 3     30  management  married   tertiary

# %%
# Também podemos buscar um dado especifico
df.loc[df['job'] == 'student'].head(3)

#Obs: antes usei este comando pra saber os bairros - df['job'].unique()
# Out:
#      idade      job marital  education default  balance housing loan  \
# 13      20  student  single  secondary      no      502      no   no
# 110     21  student  single  secondary      no     2488      no   no
# 114     25  student  single  secondary      no      331      no   no
#
#        contact  day month  duration  campaign  previous poutcome    y
# 13    cellular   30   apr       261         1         0  unknown  yes
# 110   cellular   30   jun       258         6         3  success  yes
# 114  telephone   26   aug       170         4         0  unknown  yes

# %%
# O iloc é parecido com o loc, retorna um parametro da [lunha, coluna].
df.iloc[799, 8]
# Out:
# 'cellular'

# %%
# também podemos colocar da linha até determinada linha e da coluna contact
df.iloc[1:5, 8]
# Out:
# 1    cellular
# 2    cellular
# 3     unknown
# 4     unknown
# Name: contact, dtype: object

# %%
# Outro comando [do id 0: até o id 10: de um em um,  [coluna 0, coluna 1, coluna 2]]
df.iloc[0:10:1, [0,1, 2]]
# Out:
#    idade            job  marital
# 0     30     unemployed  married
# 1     33       services  married
# 2     35     management   single
# 3     30     management  married
# 4     59    blue-collar  married
# 5     35     management   single
# 6     36  self-employed  married
# 7     39     technician  married
# 8     41   entrepreneur  married
# 9     43       services  married

# %%
# Chamada de duas linhas e duas colunas usando loc [index 0, index 5], [nomedacoluna, nomedacoluna]
df.loc[[0, 5], ['job', 'marital']]
# Out:
#           job  marital
# 0  unemployed  married
# 5  management   single

# %% [markdown]
# ### Resumo dos dados:

# %%
# Retorna a soma dos valores
df.sum()
# Retorna os menores valores
df.min()
# Retorna os maiores valores
df.max()
# Retorna a médiana dos valores (diferente da média)
df.median()
# Média dos valores
df.mean()
# Out:
# idade         41.169469
# balance     1422.721239
# day           15.918142
# duration     263.943363
# campaign       2.793805
# previous       0.541150
# dtype: float64

# %%
# Ou podemos usar o describe
df.describe()
# Out:
#              idade       balance          day     duration     campaign  \
# count  4520.000000   4520.000000  4520.000000  4520.000000  4520.000000
# mean     41.169469   1422.721239    15.918142   263.943363     2.793805
# std      10.577297   3009.968101     8.246342   259.882586     3.110128
# min      19.000000  -3313.000000     1.000000     4.000000     1.000000
# 25%      33.000000     69.000000     9.000000   104.000000     1.000000
# 50%      39.000000    444.000000    16.000000   185.000000     2.000000
# 75%      49.000000   1480.000000    21.000000   329.000000     3.000000
# max      87.000000  71188.000000    31.000000  3025.000000    50.000000
#
#           previous
# count  4520.000000
# mean      0.541150
# std       1.691023
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max      25.000000

# %%
# Também podemos fazer de determinada coluna, e não de todas

# Média de uma determinada coluna
df['balance'].mean()
# Mediana de uma determinada coluna
df['balance'].median()
# Describe de uma determinada coluna
df['balance'].describe()
# Out:
# count     4520.000000
# mean      1422.721239
# std       3009.968101
# min      -3313.000000
# 25%         69.000000
# 50%        444.000000
# 75%       1480.000000
# max      71188.000000
# Name: balance, dtype: float64

# %% [markdown]
# ###### Ordenações

# %%
# ordena pela coluna 'idade' por ordem alfabetica
df.sort_values('idade')

# ordena pela coluna 'idade' pela ordem alfabetica inversa
df.sort_values('idade', ascending = False)

# OBS: comando INPLACE
# Caso executemos esse comando ele muda direto a base de dados, sem precisar de uma outra variavel, ou seja, iria ficar ordenado
# pelo bairro.
#df.sort_values('idade', inplace = True)
# Out:
#       idade      job   marital  education default  balance housing loan  \
# 3311     87  retired   married    primary      no      230      no   no
# 1866     86  retired   married  secondary      no     1503      no   no
# 4108     84  retired  divorced    primary      no      639      no   no
# 4323     83  retired  divorced    primary      no        0      no   no
# 633      83  retired   married  secondary      no        0      no   no
# ...     ...      ...       ...        ...     ...      ...     ...  ...
# 999      20  student    single  secondary      no      291      no   no
# 503      19  student    single    primary      no      103      no   no
# 3233     19  student    single    unknown      no     1169      no   no
# 1900     19  student    single    unknown      no        0      no   no
# 2780     19  student    single  secondary      no      302      no   no
#
#         contact  day month  duration  campaign  previous poutcome    y
# 3311   cellular   30   oct       144         1         0  unknown  yes
# 1866  telephone   18   mar       165         3         1    other   no
# 4108  telephone   18   may       353         3         0  unknown  yes
# 4323  telephone   31   may       664         1         3  success   no
# 633    cellular   18   mar       140        10         0  unknown   no
# ...         ...  ...   ...       ...       ...       ...      ...  ...
# 999   telephone   11   may       172         5         5  failure   no
# 503    cellular   10   jul       104         2         0  unknown  yes
# 3233   cellular    6   feb       463        18         0  unknown   no
# 1900   cellular   11   feb       123         3         0  unknown   no
# 2780   cellular   16   jul       205         1         0  unknown  yes
#
# [4520 rows x 16 columns]

# %%
# Ordenando uma tabela por uma coluna em ordem crescente
df.sort_values(by='job').head(3)

# Ordenando uma tabela por uma coluna em ordem decrescente
df.sort_values(by='job' ,ascending = False).head(3)
# Out:
#       idade      job  marital education default  balance housing loan  \
# 95       41  unknown   single  tertiary      no     1567      no   no
# 2711     47  unknown  married   unknown      no      677      no   no
# 3385     38  unknown   single  tertiary      no        0      no   no
#
#        contact  day month  duration  campaign  previous poutcome    y
# 95    cellular    1   jul       291         2         0  unknown   no
# 2711  cellular    7   aug       384         1         4  success   no
# 3385  cellular   11   sep       260         3         3  success  yes

# %%
# Ordenação por duas colunas , 'idade' em ordem alfabetica e ordenado pelo 'balance' do menor para o maior.
df.sort_values(['idade', 'balance']).head(5)
# Out:
#       idade      job marital  education default  balance housing loan  \
# 1900     19  student  single    unknown      no        0      no   no
# 503      19  student  single    primary      no      103      no   no
# 2780     19  student  single  secondary      no      302      no   no
# 3233     19  student  single    unknown      no     1169      no   no
# 999      20  student  single  secondary      no      291      no   no
#
#         contact  day month  duration  campaign  previous poutcome    y
# 1900   cellular   11   feb       123         3         0  unknown   no
# 503    cellular   10   jul       104         2         0  unknown  yes
# 2780   cellular   16   jul       205         1         0  unknown  yes
# 3233   cellular    6   feb       463        18         0  unknown   no
# 999   telephone   11   may       172         5         5  failure   no

# %% [markdown]
# ## Filter
# O Filter serve para filtrar os dados (avá)

# %%
# Forma padrão:
df[["marital", "balance"]].head()

# Forma com o items:
df.filter(items = ["marital", "balance"]).head()
# Out:
#    marital  balance
# 0  married     1787
# 1  married     4789
# 2   single     1350
# 3  married     1476
# 4  married        0

# %%
# Usando o Like - ele busca palavras que tem nas colunas
df.filter(like = "ion").head()
# Out:
#    education  duration
# 0    primary        79
# 1  secondary       220
# 2   tertiary       185
# 3   tertiary       199
# 4  secondary       226

# %%
# Usando regex - ele busca de uma forma mais especifica colocando .algobuscado. estando no meio
# Busca no inicio
df.filter(regex = "o.").head()
# Busca no meio
df.filter(regex = ".c.").head()
# Busca no fim
df.filter(regex = ".o").head()
# Out:
#            job  education housing loan   contact month  duration  previous  \
# 0   unemployed    primary      no   no  cellular   oct        79         0
# 1     services  secondary     yes  yes  cellular   may       220         4
# 2   management   tertiary     yes   no  cellular   apr       185         1
# 3   management   tertiary     yes  yes   unknown   jun       199         0
# 4  blue-collar  secondary     yes   no   unknown   may       226         0
#
#   poutcome
# 0  unknown
# 1  failure
# 2  failure
# 3  unknown
# 4  unknown

# %% [markdown]
# Operações Lógicas - AND/OR

# %%
df[df.job == "student"].head()
# Out:
#      idade      job marital  education default  balance housing loan  \
# 13      20  student  single  secondary      no      502      no   no
# 110     21  student  single  secondary      no     2488      no   no
# 114     25  student  single  secondary      no      331      no   no
# 194     23  student  single  secondary      no     9216      no   no
# 234     30  student  single  secondary      no     3096      no   no
#
#        contact  day month  duration  campaign  previous poutcome    y
# 13    cellular   30   apr       261         1         0  unknown  yes
# 110   cellular   30   jun       258         6         3  success  yes
# 114  telephone   26   aug       170         4         0  unknown  yes
# 194   cellular    5   jun       471         2         0  unknown   no
# 234   cellular   26   jan       123         1         0  unknown   no

# %%
# Usando operação lógica AND (&)
df[(df.job == "student") & (df.marital == 'married')].head()
# Out:
#       idade      job  marital  education default  balance housing loan  \
# 284      40  student  married  secondary      no      260      no   no
# 785      23  student  married   tertiary     yes     -230     yes   no
# 1310     37  student  married    unknown      no        0      no   no
# 1599     25  student  married   tertiary      no        0     yes   no
# 2508     42  student  married    unknown      no       -7      no   no
#
#         contact  day month  duration  campaign  previous poutcome   y
# 284     unknown   20   jun       197         6         0  unknown  no
# 785    cellular   18   may       259         2         0  unknown  no
# 1310    unknown   18   jun       115         1         0  unknown  no
# 1599   cellular    9   jul       160         1         0  unknown  no
# 2508  telephone   31   jul        41         6         0  unknown  no

# %%
# Pessoas que estudam e estão casados e tem menos que 30 anos
df[(df.job == "student") & (df.marital == 'married') & (df.idade <= 30)].head()
# Out:
#       idade      job  marital education default  balance housing loan  \
# 785      23  student  married  tertiary     yes     -230     yes   no
# 1599     25  student  married  tertiary      no        0     yes   no
# 4263     25  student  married  tertiary      no       10     yes   no
#
#        contact  day month  duration  campaign  previous poutcome    y
# 785   cellular   18   may       259         2         0  unknown   no
# 1599  cellular    9   jul       160         1         0  unknown   no
# 4263  cellular   21   jul       857         4         0  unknown  yes

# %%
# Pessoas que estão casados e tem menos que 25 anos
df[(df.marital == 'married') & (df.idade <= 25)].head()
# Out:
#       idade          job  marital  education default  balance housing loan  \
# 445      24  blue-collar  married  secondary      no     1222     yes   no
# 785      23      student  married   tertiary     yes     -230     yes   no
# 918      25       admin.  married  secondary      no       18     yes   no
# 919      25  blue-collar  married  secondary      no      -76     yes   no
# 1004     24  blue-collar  married  secondary      no      204     yes  yes
#
#        contact  day month  duration  campaign  previous poutcome   y
# 445   cellular   20   apr       369         1         0  unknown  no
# 785   cellular   18   may       259         2         0  unknown  no
# 918   cellular   18   jul       225         1         0  unknown  no
# 919    unknown   12   may       241         3         0  unknown  no
# 1004  cellular   17   apr       229         3         0  unknown  no

# %%
# Usando operação lógica AND (&) escolhendo com determinadas colunas
df[(df.idade >= 30) & (df.job == "admin.")][["idade", "job", "marital"]].head()
# Out:
#     idade     job   marital
# 11     43  admin.   married
# 17     37  admin.    single
# 29     53  admin.   married
# 35     42  admin.  divorced
# 49     61  admin.   married

# %%
# Usando operação lógica OR (|)
# Pessoa que tem mais de 60 anos e seja casado ou divorciado
df[(df.idade >= 60) & ((df.marital == "married" ) | (df.marital == "divorced"))].head()
# Out:
#     idade      job   marital  education default  balance housing loan  \
# 27     67  retired   married    unknown      no      696      no   no
# 30     68  retired  divorced  secondary      no     4189      no   no
# 36     78  retired  divorced    primary      no      229      no   no
# 49     61   admin.   married    unknown      no     4629     yes   no
# 61     63  retired   married  secondary      no      415     yes   no
#
#       contact  day month  duration  campaign  previous poutcome    y
# 27  telephone   17   aug       119         1         2  failure   no
# 30  telephone   14   jul       897         2         0  unknown  yes
# 36  telephone   22   oct        97         1         0  unknown  yes
# 49   cellular   27   jan       181         1         1  success  yes
# 61   cellular    7   oct       323         1         0  unknown   no

# %%
# Usando o isin para mais de uma operação (Retorna True e False)
filtro = df.isin({"marital" : ["single"], "balance": [0], "contact": ['cellular']})

# %%
# '82' pessoas são solteiras e tem 0' de balanço e tem um contato como 'cellular'
# df . shape - 1996, 7
df[(filtro.marital) & (filtro.balance)].shape
# Out:
# (82, 16)

# %% [markdown]
# ## GroupBy
# O GroupBy serve para agrupar os dados de uma forma especifica, da mesma forma do SQL

# %%
# Retorna a média das pessoas com 'divorced', 'married', 'single'
df.groupby('marital').mean()
# Out:
#               idade      balance        day    duration  campaign  previous
# marital
# divorced  45.475379  1122.390152  15.753788  279.232955  2.604167  0.439394
# married   43.454415  1463.195567  15.905971  256.528781  2.847336  0.519128
# single    33.918828  1460.686192  16.019247  274.542259  2.752301  0.637657

# %%
df[["marital", "education", "idade"]].groupby(["marital", "education"]).mean()
# Out:
#                         idade
# marital  education
# divorced primary    51.392405
#          secondary  43.496296
#          tertiary   45.148387
#          unknown    50.375000
# married  primary    47.511407
#          secondary  42.404345
#          tertiary   41.777166
#          unknown    48.444444
# single   primary    37.013699
#          secondary  33.052545
#          tertiary   34.492505
#          unknown    34.652174

# %%
# Média do balanço de pessoas com idade entre 30 e 50 anos, casadas e separadas
colunas = ["balance", "marital"]
df[(df.idade >= 30) & (df.idade <= 50)].head()
# Out:
#    idade         job  marital  education default  balance housing loan  \
# 0     30  unemployed  married    primary      no     1787      no   no
# 1     33    services  married  secondary      no     4789     yes  yes
# 2     35  management   single   tertiary      no     1350     yes   no
# 3     30  management  married   tertiary      no     1476     yes  yes
# 5     35  management   single   tertiary      no      747      no   no
#
#     contact  day month  duration  campaign  previous poutcome   y
# 0  cellular   19   oct        79         1         0  unknown  no
# 1  cellular   11   may       220         1         4  failure  no
# 2  cellular   16   apr       185         1         1  failure  no
# 3   unknown    3   jun       199         4         0  unknown  no
# 5  cellular   23   feb       141         2         3  failure  no

# %%
# Média do balanço de pessoas com idade entre 30 e 50 anos, casadas e separadas - Outra forma de fazer
colunas = ["balance", "marital"]
df[((df.idade >= 30) & (df.idade <= 50)) & (df.marital.isin(["married", "divorced"]))].shape
# Out:
# (2300, 16)

# %% [markdown]
# ## Cores no dataframe (Styler)
# Documentação: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.io.formats.style.Styler.html

# %%
# pra isso, vamos usar apenas os relacionamentos como casados
df_married = df[df.marital == 'married'].tail(30)

# %%
# destaca todos os maiores números de todas as colunas (apenas inteiros)
df_married.style.highlight_max(color = 'green')
# Out:
# <style  type="text/css" >
#     #T_72523978_97b8_11ea_ab18_24f5aa59b372row5_col9 {
#             background-color:  green;
#         }    #T_72523978_97b8_11ea_ab18_24f5aa59b372row9_col13 {
#             background-color:  green;
#         }    #T_72523978_97b8_11ea_ab18_24f5aa59b372row9_col14 {
#             background-color:  green;
#         }    #T_72523978_97b8_11ea_ab18_24f5aa59b372row11_col5 {
#             background-color:  green;
#         }    #T_72523978_97b8_11ea_ab18_24f5aa59b372row13_col11 {
#             background-color:  green;
#         }    #T_72523978_97b8_11ea_ab18_24f5aa59b372row18_col0 {
#             background-color:  green;
#         }    #T_72523978_97b8_11ea_ab18_24f5aa59b372row28_col12 {
#             background-color:  green;
#         }</style><table id="T_72523978_97b8_11ea_ab18_24f5aa59b372" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >age</th>        <th class="col_heading level0 col1" >job</th>        <th class="col_heading level0 col2" >marital</th>        <th class="col_heading level0 col3" >education</th>        <th class="col_heading level0 col4" >default</th>        <th class="col_heading level0 col5" >balance</th>        <th class="col_heading level0 col6" >housing</th>        <th class="col_heading level0 col7" >loan</th>        <th class="col_heading level0 col8" >contact</th>        <th class="col_heading level0 col9" >day</th>        <th class="col_heading level0 col10" >month</th>        <th class="col_heading level0 col11" >duration</th>        <th class="col_heading level0 col12" >campaign</th>        <th class="col_heading level0 col13" >pdays</th>        <th class="col_heading level0 col14" >previous</th>        <th class="col_heading level0 col15" >poutcome</th>        <th class="col_heading level0 col16" >y</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_72523978_97b8_11ea_ab18_24f5aa59b372level0_row0" class="row_heading level0 row0" >4474</th>
#                         <td id="T_72523978_97b8_11ea_ab18_24f5aa59b372row0_col0" class="data row0 col0" >44</td>
#                         <td id="T_72523978_97b8_11ea_ab18_24f5aa59b372row0_col1" class="data row0 col1" >blue-collar</td>
#                         <td id="T_72523978_97b8_11ea_ab18_24f5aa59b372row0_col2" class="data row0 col2" >married</td>
#                         <td id="T_72523978_97b8_11ea_ab18_24f5aa59b372row0_col3" class="data row0 col3" >primary</td>
#                         <td id="T_72523978_97b8_11ea_ab18_24f5aa59b372row0_col4" class="data row0 col4" >no</td>
#                         <td id="T_72523978_97b8_11ea_ab18_24f5aa59b372row0_col5" class="data row0 col5" >-237</td>
#                         <td id="T_72523978_97b8_11ea_ab18_24f5aa59b372row0_col6" class="data row0 col6" >yes</td>
#                         <td id="T_72523978_97b8_11ea_ab18_24f5aa59b372row0_col7" class="data row0 col7" >no</td>
#                         <td id="T_72523978_97b8_11ea_ab18_24f5aa59b372row0_col8" class="data row0 col8" >telephone</td>
#                         <td id="T_72523978_97b8_11ea_ab18_24f5aa59b372row0_col9" class="data row0 col9" >10</td>
#                         <td id="T_72523978_97b8_11ea_ab18_24f5aa59b372row0_col10" class="data row0 col10" >jul</td>
#                         <td id="T_72523978_97b8_11ea_ab18_24f5aa59b372row0_col11" class="data row0 col11" >73</td>
#                         <td id="T_72523978_97b8_11ea_ab18_24f5aa59b372row0_col12" class="data row0 col12" >1</td>
#                         <td id="T_72523978_97b8_11ea_ab18_24f5aa59b372row0_col13" class="data row0 col13" >-1</td>
#                         <td id="T_72523978_97b8_11ea_ab18_24f5aa59b372row0_col14" class="data row0 col14" >0</td>
#                         <td id="T_72523978_97b8_11ea_ab18_24f5aa59b372row0_col15" class="data row0 col15" >unknown</td>
#                         <td id="T_72523978_97b8_11ea_ab18_24f5aa59b372row0_col16" class="data row0 col16" >no</td>
#             </tr>
#             <tr>
#                         <th id="T_72523978_97b8_11ea_ab18_24f5aa59b372level0_row1" class="row_heading level0 row1" >4475</th>
#                         <td id="T_72523978_97b8_11ea_ab18_24f5aa59b372row1_col0" class="data row1 col0" >43</td>
#                         <td id="T_72523978_97b8_11ea_ab18_24f5aa59b372row1_col1" class="data row1 col1" >blue-collar</td>
#                         <td id="T_72523978_97b8_11ea_ab18_24f5aa59b372row1_col2" class="data row1 col2" >married</td>
#                         <td id="T_72523978_97b8_11ea_ab18_24f5aa59b372row1_col3" class="data row1 col3" >secondary</td>
#                         <td id="T_72523978_97b8_11ea_ab18_24f5aa59b372row1_col4" class="data row1 col4" >no</td>
#                         <td id="T_72523978_97b8_11ea_ab18_24f5aa59b372row1_col5" class="data row1 col5" >1335</td>
#                         <td id="T_72523978_97b8_11ea_ab18_24f5aa59b372row1_col6" class="data row1 col6" >yes</td>
#                         <td id="T_72523978_97b8_11ea_ab18_24f5aa59b372row1_col7" class="data row1 col7" >no</td>
#                         <td id="T_72523978_97b8_11ea_ab18_24f5aa59b372row1_col8" class="data row1 col8" >unknown</td>
#                         <td id="T_72523978_97b8_11ea_ab18_24f5aa59b372row1_col9" class="data row1 col9" >6</td>
#                         <td id="T_72523978_97b8_11ea_ab18_24f5aa59b372row1_col10" class="data row1 col10" >may</td>
#                         <td id="T_72523978_97b8_11ea_ab18_24f5aa59b372row1_col11" class="data row1 col11" >371</td>
#                         <td id="T_72523978_97b8_11ea_ab18_24f5aa59b372row1_col12" class="data row1 col12" >2</td>
#                         <td id="T_72523978_97b8_11ea_ab18_24f5aa59b372row1_col13" class="data row1 col13" >-1</td>
#                         <td id="T_72523978_97b8_11ea_ab18_24f5aa59b372row1_col14" class="data row1 col14" >0</td>
#                         <td id="T_72523978_97b8_11ea_ab18_24f5aa59b372row1_col15" class="data row1 col15" >unknown</td>
#                         <td id="T_72523978_97b8_11ea_ab18_24f5aa59b372row1_col16" class="data row1 col16" >no</td>
#             </tr>
#             <tr>
#                         <th id="T_72523978_97b8_11ea_ab18_24f5aa59b372level0_row2" class="row_heading level0 row2" >4476</th>
#                         <td id="T_72523978_97b8_11ea_ab18_24f5aa59b372row2_col0" class="data row2 col0" >42</td>
#                         <td id="T_72523978_97b8_11ea_ab18_24f5aa59b372row2_col1" class="data row2 col1" >management</td>
#                         <td id="T_72523978_97b8_11ea_ab18_24f5aa59b372row2_col2" class="data row2 col2" >married</td>
#                         <td id="T_72523978_97b8_11ea_ab18_24f5aa59b372row2_col3" class="data row2 col3" >tertiary</td>
#                         <td id="T_72523978_97b8_11ea_ab18_24f5aa59b372row2_col4" class="data row2 col4" >no</td>
#                         <td id="T_72523978_97b8_11ea_ab18_24f5aa59b372row2_col5" class="data row2 col5" >603</td>
#                         <td id="T_72523978_97b8_11ea_ab18_24f5aa59b372row2_col6" class="data row2 col6" >yes</td>
#                         <td id="T_72523978_97b8_11ea_ab18_24f5aa59b372row2_col7" class="data row2 col7" >no</td>
#                         <td id="T_72523978_97b8_11ea_ab18_24f5aa59b372row2_col8" class="data row2 col8" >cellular</td>
#                         <td id="T_72523978_97b8_11ea_ab18_24f5aa59b372row2_col9" class="data row2 col9" >5</td>
#                         <td id="T_72523978_97b8_11ea_ab18_24f5aa59b372row2_col10" class="data row2 col10" >nov</td>
#                         <td id="T_72523978_97b8_11ea_ab18_24f5aa59b372row2_col11" class="data row2 col11" >298</td>
#                         <td id="T_72523978_97b8_11ea_ab18_24f5aa59b372row2_col12" class="data row2 col12" >5</td>
#                         <td id="T_72523978_97b8_11ea_ab18_24f5aa59b372row2_col13" class="data row2 col13" >-1</td>
#                         <td id="T_72523978_97b8_11ea_ab18_24f5aa59b372row2_col14" class="data row2 col14" >0</td>

# %%
# destaca todos os menores números de todas as colunas (apenas inteiros)
df_married.style.highlight_min(color = 'red')
# Out:
# <style  type="text/css" >
#     #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row0_col12 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row0_col13 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row0_col14 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row1_col13 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row1_col14 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row2_col13 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row2_col14 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row3_col12 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row3_col13 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row3_col14 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row4_col0 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row4_col12 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row4_col13 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row4_col14 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row5_col13 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row5_col14 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row6_col12 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row6_col13 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row6_col14 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row7_col12 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row7_col13 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row7_col14 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row8_col13 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row8_col14 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row10_col12 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row10_col13 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row10_col14 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row12_col9 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row12_col13 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row12_col14 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row13_col13 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row13_col14 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row14_col13 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row14_col14 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row15_col13 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row15_col14 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row16_col13 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row16_col14 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row17_col11 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row17_col12 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row17_col13 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row17_col14 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row18_col13 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row18_col14 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row19_col12 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row19_col13 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row19_col14 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row20_col13 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row20_col14 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row21_col13 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row21_col14 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row22_col13 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row22_col14 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row23_col13 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row23_col14 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row24_col13 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row24_col14 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row26_col13 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row26_col14 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row27_col5 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row27_col12 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row27_col13 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row27_col14 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row28_col13 {
#             background-color:  red;
#         }    #T_67c5499e_97b8_11ea_99f1_24f5aa59b372row28_col14 {
#             background-color:  red;
#         }</style><table id="T_67c5499e_97b8_11ea_99f1_24f5aa59b372" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >age</th>        <th class="col_heading level0 col1" >job</th>        <th class="col_heading level0 col2" >marital</th>        <th class="col_heading level0 col3" >education</th>        <th class="col_heading level0 col4" >default</th>        <th class="col_heading level0 col5" >balance</th>        <th class="col_heading level0 col6" >housing</th>        <th class="col_heading level0 col7" >loan</th>        <th class="col_heading level0 col8" >contact</th>        <th class="col_heading level0 col9" >day</th>        <th class="col_heading level0 col10" >month</th>        <th class="col_heading level0 col11" >duration</th>        <th class="col_heading level0 col12" >campaign</th>        <th class="col_heading level0 col13" >pdays</th>        <th class="col_heading level0 col14" >previous</th>        <th class="col_heading level0 col15" >poutcome</th>        <th class="col_heading level0 col16" >y</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_67c5499e_97b8_11ea_99f1_24f5aa59b372level0_row0" class="row_heading level0 row0" >4474</th>
#                         <td id="T_67c5499e_97b8_11ea_99f1_24f5aa59b372row0_col0" class="data row0 col0" >44</td>

# %%
# também podemos especficar apenas para uma coluna especifica no caso balance
df_married.style.highlight_max(subset=['balance'], color = 'green')
# tanto maior quanto menor
df_married.style.highlight_min(subset=['balance'], color = 'red')
# Out:
# <style  type="text/css" >
#     #T_9500aa66_97b8_11ea_b346_24f5aa59b372row27_col5 {
#             background-color:  red;
#         }</style><table id="T_9500aa66_97b8_11ea_b346_24f5aa59b372" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >age</th>        <th class="col_heading level0 col1" >job</th>        <th class="col_heading level0 col2" >marital</th>        <th class="col_heading level0 col3" >education</th>        <th class="col_heading level0 col4" >default</th>        <th class="col_heading level0 col5" >balance</th>        <th class="col_heading level0 col6" >housing</th>        <th class="col_heading level0 col7" >loan</th>        <th class="col_heading level0 col8" >contact</th>        <th class="col_heading level0 col9" >day</th>        <th class="col_heading level0 col10" >month</th>        <th class="col_heading level0 col11" >duration</th>        <th class="col_heading level0 col12" >campaign</th>        <th class="col_heading level0 col13" >pdays</th>        <th class="col_heading level0 col14" >previous</th>        <th class="col_heading level0 col15" >poutcome</th>        <th class="col_heading level0 col16" >y</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9500aa66_97b8_11ea_b346_24f5aa59b372level0_row0" class="row_heading level0 row0" >4474</th>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row0_col0" class="data row0 col0" >44</td>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row0_col1" class="data row0 col1" >blue-collar</td>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row0_col2" class="data row0 col2" >married</td>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row0_col3" class="data row0 col3" >primary</td>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row0_col4" class="data row0 col4" >no</td>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row0_col5" class="data row0 col5" >-237</td>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row0_col6" class="data row0 col6" >yes</td>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row0_col7" class="data row0 col7" >no</td>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row0_col8" class="data row0 col8" >telephone</td>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row0_col9" class="data row0 col9" >10</td>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row0_col10" class="data row0 col10" >jul</td>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row0_col11" class="data row0 col11" >73</td>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row0_col12" class="data row0 col12" >1</td>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row0_col13" class="data row0 col13" >-1</td>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row0_col14" class="data row0 col14" >0</td>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row0_col15" class="data row0 col15" >unknown</td>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row0_col16" class="data row0 col16" >no</td>
#             </tr>
#             <tr>
#                         <th id="T_9500aa66_97b8_11ea_b346_24f5aa59b372level0_row1" class="row_heading level0 row1" >4475</th>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row1_col0" class="data row1 col0" >43</td>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row1_col1" class="data row1 col1" >blue-collar</td>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row1_col2" class="data row1 col2" >married</td>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row1_col3" class="data row1 col3" >secondary</td>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row1_col4" class="data row1 col4" >no</td>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row1_col5" class="data row1 col5" >1335</td>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row1_col6" class="data row1 col6" >yes</td>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row1_col7" class="data row1 col7" >no</td>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row1_col8" class="data row1 col8" >unknown</td>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row1_col9" class="data row1 col9" >6</td>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row1_col10" class="data row1 col10" >may</td>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row1_col11" class="data row1 col11" >371</td>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row1_col12" class="data row1 col12" >2</td>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row1_col13" class="data row1 col13" >-1</td>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row1_col14" class="data row1 col14" >0</td>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row1_col15" class="data row1 col15" >unknown</td>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row1_col16" class="data row1 col16" >no</td>
#             </tr>
#             <tr>
#                         <th id="T_9500aa66_97b8_11ea_b346_24f5aa59b372level0_row2" class="row_heading level0 row2" >4476</th>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row2_col0" class="data row2 col0" >42</td>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row2_col1" class="data row2 col1" >management</td>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row2_col2" class="data row2 col2" >married</td>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row2_col3" class="data row2 col3" >tertiary</td>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row2_col4" class="data row2 col4" >no</td>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row2_col5" class="data row2 col5" >603</td>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row2_col6" class="data row2 col6" >yes</td>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row2_col7" class="data row2 col7" >no</td>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row2_col8" class="data row2 col8" >cellular</td>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row2_col9" class="data row2 col9" >5</td>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row2_col10" class="data row2 col10" >nov</td>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row2_col11" class="data row2 col11" >298</td>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row2_col12" class="data row2 col12" >5</td>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row2_col13" class="data row2 col13" >-1</td>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row2_col14" class="data row2 col14" >0</td>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row2_col15" class="data row2 col15" >unknown</td>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row2_col16" class="data row2 col16" >no</td>
#             </tr>
#             <tr>
#                         <th id="T_9500aa66_97b8_11ea_b346_24f5aa59b372level0_row3" class="row_heading level0 row3" >4478</th>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row3_col0" class="data row3 col0" >43</td>
#                         <td id="T_9500aa66_97b8_11ea_b346_24f5aa59b372row3_col1" class="data row3 col1" >management</td>

# %% [markdown]
# # Estilos determinados:
# Estilos: https://matplotlib.org/3.2.1/tutorials/colors/colormaps.html

# %%
# também podemos usar estilos determinados, (apenas os inteiros)
df_married.style.background_gradient(cmap= 'viridis')
# entre outros
df_married.style.background_gradient(cmap= 'Reds')
# Out:
# <style  type="text/css" >
#     #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row0_col0 {
#             background-color:  #f4503a;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row0_col5 {
#             background-color:  #fcab8f;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row0_col9 {
#             background-color:  #fcb398;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row0_col11 {
#             background-color:  #fff2eb;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row0_col12 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row0_col13 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row0_col14 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row1_col0 {
#             background-color:  #f75b40;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row1_col5 {
#             background-color:  #fb7a5a;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row1_col9 {
#             background-color:  #fedccd;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row1_col11 {
#             background-color:  #fcc2aa;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row1_col12 {
#             background-color:  #fee5d8;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row1_col13 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row1_col14 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row2_col0 {
#             background-color:  #fa6547;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row2_col5 {
#             background-color:  #fc9070;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row2_col9 {
#             background-color:  #fee4d8;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row2_col11 {
#             background-color:  #fdd1be;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row2_col12 {
#             background-color:  #fc8a6a;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row2_col13 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row2_col14 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row3_col0 {
#             background-color:  #f75b40;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row3_col5 {
#             background-color:  #fca486;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row3_col9 {
#             background-color:  #f96346;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row3_col11 {
#             background-color:  #ffeee6;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row3_col12 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row3_col13 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row3_col14 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row4_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row4_col5 {
#             background-color:  #fc7f5f;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row4_col9 {
#             background-color:  #fb7050;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row4_col11 {
#             background-color:  #fb6d4d;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row4_col12 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row4_col13 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row4_col14 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row5_col0 {
#             background-color:  #f75b40;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row5_col5 {
#             background-color:  #fc8f6f;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row5_col9 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row5_col11 {
#             background-color:  #fc8464;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row5_col12 {
#             background-color:  #fee5d8;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row5_col13 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row5_col14 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row6_col0 {
#             background-color:  #ef3c2c;
#             color:  #f1f1f1;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row6_col5 {
#             background-color:  #fc9474;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row6_col9 {
#             background-color:  #880811;
#             color:  #f1f1f1;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row6_col11 {
#             background-color:  #fee7db;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row6_col12 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row6_col13 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row6_col14 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row7_col0 {
#             background-color:  #fdc5ae;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row7_col5 {
#             background-color:  #fca082;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row7_col9 {
#             background-color:  #feeae0;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row7_col11 {
#             background-color:  #fcbfa7;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row7_col12 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row7_col13 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row7_col14 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row8_col0 {
#             background-color:  #fc8969;
#             color:  #000000;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row8_col5 {
#             background-color:  #e53228;
#             color:  #f1f1f1;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row8_col9 {
#             background-color:  #e63328;
#             color:  #f1f1f1;
#         }    #T_0f25cd24_97b9_11ea_9b45_24f5aa59b372row8_col11 {
#             background-color:  #fc8060;

# %% [markdown]
# Estilos feitos manualmente:

# %%
df_married.style.set_properties(**{'background-color': 'black',
                                  'color': 'lawngreen',
                                  'border-color': 'white'})
# Out:
# <style  type="text/css" >
#     #T_7245ad5e_97b9_11ea_beaa_24f5aa59b372row0_col0 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7245ad5e_97b9_11ea_beaa_24f5aa59b372row0_col1 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7245ad5e_97b9_11ea_beaa_24f5aa59b372row0_col2 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7245ad5e_97b9_11ea_beaa_24f5aa59b372row0_col3 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7245ad5e_97b9_11ea_beaa_24f5aa59b372row0_col4 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7245ad5e_97b9_11ea_beaa_24f5aa59b372row0_col5 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7245ad5e_97b9_11ea_beaa_24f5aa59b372row0_col6 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7245ad5e_97b9_11ea_beaa_24f5aa59b372row0_col7 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7245ad5e_97b9_11ea_beaa_24f5aa59b372row0_col8 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7245ad5e_97b9_11ea_beaa_24f5aa59b372row0_col9 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7245ad5e_97b9_11ea_beaa_24f5aa59b372row0_col10 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7245ad5e_97b9_11ea_beaa_24f5aa59b372row0_col11 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7245ad5e_97b9_11ea_beaa_24f5aa59b372row0_col12 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7245ad5e_97b9_11ea_beaa_24f5aa59b372row0_col13 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7245ad5e_97b9_11ea_beaa_24f5aa59b372row0_col14 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7245ad5e_97b9_11ea_beaa_24f5aa59b372row0_col15 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7245ad5e_97b9_11ea_beaa_24f5aa59b372row0_col16 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7245ad5e_97b9_11ea_beaa_24f5aa59b372row1_col0 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7245ad5e_97b9_11ea_beaa_24f5aa59b372row1_col1 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7245ad5e_97b9_11ea_beaa_24f5aa59b372row1_col2 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7245ad5e_97b9_11ea_beaa_24f5aa59b372row1_col3 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7245ad5e_97b9_11ea_beaa_24f5aa59b372row1_col4 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7245ad5e_97b9_11ea_beaa_24f5aa59b372row1_col5 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7245ad5e_97b9_11ea_beaa_24f5aa59b372row1_col6 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7245ad5e_97b9_11ea_beaa_24f5aa59b372row1_col7 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7245ad5e_97b9_11ea_beaa_24f5aa59b372row1_col8 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7245ad5e_97b9_11ea_beaa_24f5aa59b372row1_col9 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7245ad5e_97b9_11ea_beaa_24f5aa59b372row1_col10 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7245ad5e_97b9_11ea_beaa_24f5aa59b372row1_col11 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7245ad5e_97b9_11ea_beaa_24f5aa59b372row1_col12 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7245ad5e_97b9_11ea_beaa_24f5aa59b372row1_col13 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7245ad5e_97b9_11ea_beaa_24f5aa59b372row1_col14 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7245ad5e_97b9_11ea_beaa_24f5aa59b372row1_col15 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7245ad5e_97b9_11ea_beaa_24f5aa59b372row1_col16 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7245ad5e_97b9_11ea_beaa_24f5aa59b372row2_col0 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7245ad5e_97b9_11ea_beaa_24f5aa59b372row2_col1 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7245ad5e_97b9_11ea_beaa_24f5aa59b372row2_col2 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7245ad5e_97b9_11ea_beaa_24f5aa59b372row2_col3 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7245ad5e_97b9_11ea_beaa_24f5aa59b372row2_col4 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7245ad5e_97b9_11ea_beaa_24f5aa59b372row2_col5 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7245ad5e_97b9_11ea_beaa_24f5aa59b372row2_col6 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7245ad5e_97b9_11ea_beaa_24f5aa59b372row2_col7 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7245ad5e_97b9_11ea_beaa_24f5aa59b372row2_col8 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7245ad5e_97b9_11ea_beaa_24f5aa59b372row2_col9 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7245ad5e_97b9_11ea_beaa_24f5aa59b372row2_col10 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7245ad5e_97b9_11ea_beaa_24f5aa59b372row2_col11 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7245ad5e_97b9_11ea_beaa_24f5aa59b372row2_col12 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_7245ad5e_97b9_11ea_beaa_24f5aa59b372row2_col13 {
#             background-color:  black;
#             co

# %%
# mudando o hover (passar o mouse emcima)
df_married.style.set_table_styles([{'selector': 'tr:hover',
                                   'props': [('background-color', 'red'), ('color', 'white')]}])
# Out:
# <style  type="text/css" >
#     #T_000a0f4a_97ba_11ea_8443_24f5aa59b372 tr:hover {
#           background-color: red;
#           color: white;
#     }</style><table id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >age</th>        <th class="col_heading level0 col1" >job</th>        <th class="col_heading level0 col2" >marital</th>        <th class="col_heading level0 col3" >education</th>        <th class="col_heading level0 col4" >default</th>        <th class="col_heading level0 col5" >balance</th>        <th class="col_heading level0 col6" >housing</th>        <th class="col_heading level0 col7" >loan</th>        <th class="col_heading level0 col8" >contact</th>        <th class="col_heading level0 col9" >day</th>        <th class="col_heading level0 col10" >month</th>        <th class="col_heading level0 col11" >duration</th>        <th class="col_heading level0 col12" >campaign</th>        <th class="col_heading level0 col13" >pdays</th>        <th class="col_heading level0 col14" >previous</th>        <th class="col_heading level0 col15" >poutcome</th>        <th class="col_heading level0 col16" >y</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372level0_row0" class="row_heading level0 row0" >4474</th>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row0_col0" class="data row0 col0" >44</td>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row0_col1" class="data row0 col1" >blue-collar</td>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row0_col2" class="data row0 col2" >married</td>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row0_col3" class="data row0 col3" >primary</td>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row0_col4" class="data row0 col4" >no</td>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row0_col5" class="data row0 col5" >-237</td>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row0_col6" class="data row0 col6" >yes</td>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row0_col7" class="data row0 col7" >no</td>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row0_col8" class="data row0 col8" >telephone</td>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row0_col9" class="data row0 col9" >10</td>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row0_col10" class="data row0 col10" >jul</td>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row0_col11" class="data row0 col11" >73</td>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row0_col12" class="data row0 col12" >1</td>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row0_col13" class="data row0 col13" >-1</td>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row0_col14" class="data row0 col14" >0</td>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row0_col15" class="data row0 col15" >unknown</td>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row0_col16" class="data row0 col16" >no</td>
#             </tr>
#             <tr>
#                         <th id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372level0_row1" class="row_heading level0 row1" >4475</th>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row1_col0" class="data row1 col0" >43</td>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row1_col1" class="data row1 col1" >blue-collar</td>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row1_col2" class="data row1 col2" >married</td>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row1_col3" class="data row1 col3" >secondary</td>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row1_col4" class="data row1 col4" >no</td>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row1_col5" class="data row1 col5" >1335</td>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row1_col6" class="data row1 col6" >yes</td>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row1_col7" class="data row1 col7" >no</td>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row1_col8" class="data row1 col8" >unknown</td>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row1_col9" class="data row1 col9" >6</td>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row1_col10" class="data row1 col10" >may</td>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row1_col11" class="data row1 col11" >371</td>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row1_col12" class="data row1 col12" >2</td>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row1_col13" class="data row1 col13" >-1</td>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row1_col14" class="data row1 col14" >0</td>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row1_col15" class="data row1 col15" >unknown</td>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row1_col16" class="data row1 col16" >no</td>
#             </tr>
#             <tr>
#                         <th id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372level0_row2" class="row_heading level0 row2" >4476</th>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row2_col0" class="data row2 col0" >42</td>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row2_col1" class="data row2 col1" >management</td>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row2_col2" class="data row2 col2" >married</td>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row2_col3" class="data row2 col3" >tertiary</td>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row2_col4" class="data row2 col4" >no</td>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row2_col5" class="data row2 col5" >603</td>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row2_col6" class="data row2 col6" >yes</td>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row2_col7" class="data row2 col7" >no</td>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row2_col8" class="data row2 col8" >cellular</td>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row2_col9" class="data row2 col9" >5</td>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row2_col10" class="data row2 col10" >nov</td>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row2_col11" class="data row2 col11" >298</td>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row2_col12" class="data row2 col12" >5</td>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row2_col13" class="data row2 col13" >-1</td>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row2_col14" class="data row2 col14" >0</td>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row2_col15" class="data row2 col15" >unknown</td>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row2_col16" class="data row2 col16" >no</td>
#             </tr>
#             <tr>
#                         <th id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372level0_row3" class="row_heading level0 row3" >4478</th>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row3_col0" class="data row3 col0" >43</td>
#                         <td id="T_000a0f4a_97ba_11ea_8443_24f5aa59b372row3_col1" class="data row3 col1" >management<
